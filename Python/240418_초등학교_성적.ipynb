# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-comic/profile/blob/main/240418_%EC%B4%88%EB%93%B1%ED%95%99%EA%B5%90_%EC%84%B1%EC%A0%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random

# %%
점수모음 = []
for i in range(72):
    과목점수모음 = []
    for j in range(20):
        점수 = random.randint(0, 100)
        과목점수모음.append(점수)
    점수모음.append(과목점수모음)

# %%
학년1반1 = {"국어":점수모음[0], "영어":점수모음[1], "수학":점수모음[2]}
학년1반2 = {"국어":점수모음[3], "영어":점수모음[4], "수학":점수모음[5]}
학년1반3 = {"국어":점수모음[6], "영어":점수모음[7], "수학":점수모음[8]}
학년1반4 = {"국어":점수모음[9], "영어":점수모음[10], "수학":점수모음[11]}

학년2반1 = {"국어":점수모음[12], "영어":점수모음[13], "수학":점수모음[14]}
학년2반2 = {"국어":점수모음[15], "영어":점수모음[16], "수학":점수모음[17]}
학년2반3 = {"국어":점수모음[18], "영어":점수모음[19], "수학":점수모음[20]}
학년2반4 = {"국어":점수모음[21], "영어":점수모음[21], "수학":점수모음[23]}

학년3반1 = {"국어":점수모음[24], "영어":점수모음[25], "수학":점수모음[26]}
학년3반2 = {"국어":점수모음[27], "영어":점수모음[28], "수학":점수모음[29]}
학년3반3 = {"국어":점수모음[30], "영어":점수모음[31], "수학":점수모음[32]}
학년3반4 = {"국어":점수모음[33], "영어":점수모음[34], "수학":점수모음[35]}

학년4반1 = {"국어":점수모음[36], "영어":점수모음[37], "수학":점수모음[38]}
학년4반2 = {"국어":점수모음[39], "영어":점수모음[40], "수학":점수모음[41]}
학년4반3 = {"국어":점수모음[42], "영어":점수모음[43], "수학":점수모음[44]}
학년4반4 = {"국어":점수모음[45], "영어":점수모음[46], "수학":점수모음[47]}

학년5반1 = {"국어":점수모음[48], "영어":점수모음[49], "수학":점수모음[50]}
학년5반2 = {"국어":점수모음[51], "영어":점수모음[52], "수학":점수모음[53]}
학년5반3 = {"국어":점수모음[54], "영어":점수모음[55], "수학":점수모음[56]}
학년5반4 = {"국어":점수모음[57], "영어":점수모음[58], "수학":점수모음[59]}

학년6반1 = {"국어":점수모음[60], "영어":점수모음[61], "수학":점수모음[62]}
학년6반2 = {"국어":점수모음[63], "영어":점수모음[64], "수학":점수모음[65]}
학년6반3 = {"국어":점수모음[66], "영어":점수모음[67], "수학":점수모음[68]}
학년6반4 = {"국어":점수모음[69], "영어":점수모음[70], "수학":점수모음[71]}

# %%
점수합계1학년국어 = sum(학년1반1["국어"]) + sum(학년1반2["국어"]) + sum(학년1반3["국어"]) + sum(학년1반4["국어"])
점수평균1학년국어 = 점수합계1학년국어 / 80

점수합계1학년영어 = sum(학년1반1["영어"]) + sum(학년1반2["영어"]) + sum(학년1반3["영어"]) + sum(학년1반4["영어"])
점수평균1학년영어 = 점수합계1학년영어 / 80

점수합계1학년수학 = sum(학년1반1["수학"]) + sum(학년1반2["수학"]) + sum(학년1반3["수학"]) + sum(학년1반4["수학"])
점수평균1학년수학 = 점수합계1학년수학 / 80

점수합계2학년국어 = sum(학년2반1["국어"]) + sum(학년2반2["국어"]) + sum(학년2반3["국어"]) + sum(학년2반4["국어"])
점수평균2학년국어 = 점수합계2학년국어 / 80

점수합계2학년영어 = sum(학년2반1["영어"]) + sum(학년2반2["영어"]) + sum(학년2반3["영어"]) + sum(학년2반4["영어"])
점수평균2학년영어 = 점수합계2학년영어 / 80

점수합계2학년수학 = sum(학년2반1["수학"]) + sum(학년2반2["수학"]) + sum(학년2반3["수학"]) + sum(학년2반4["수학"])
점수평균2학년수학 = 점수합계2학년수학 / 80

점수합계3학년국어 = sum(학년3반1["국어"]) + sum(학년3반2["국어"]) + sum(학년3반3["국어"]) + sum(학년3반4["국어"])
점수평균3학년국어 = 점수합계3학년국어 / 80

점수합계3학년영어 = sum(학년3반1["영어"]) + sum(학년3반2["영어"]) + sum(학년3반3["영어"]) + sum(학년3반4["영어"])
점수평균3학년영어 = 점수합계3학년영어 / 80

점수합계3학년수학 = sum(학년3반1["수학"]) + sum(학년3반2["수학"]) + sum(학년3반3["수학"]) + sum(학년3반4["수학"])
점수평균3학년수학 = 점수합계3학년수학 / 80

점수합계4학년국어 = sum(학년4반1["국어"]) + sum(학년4반2["국어"]) + sum(학년4반3["국어"]) + sum(학년4반4["국어"])
점수평균4학년국어 = 점수합계4학년국어 / 80

점수합계4학년영어 = sum(학년4반1["영어"]) + sum(학년4반2["영어"]) + sum(학년4반3["영어"]) + sum(학년4반4["영어"])
점수평균4학년영어 = 점수합계4학년영어 / 80

점수합계4학년수학 = sum(학년4반1["수학"]) + sum(학년4반2["수학"]) + sum(학년4반3["수학"]) + sum(학년4반4["수학"])
점수평균4학년수학 = 점수합계4학년수학 / 80

점수합계5학년국어 = sum(학년5반1["국어"]) + sum(학년5반2["국어"]) + sum(학년5반3["국어"]) + sum(학년5반4["국어"])
점수평균5학년국어 = 점수합계5학년국어 / 80

점수합계5학년영어 = sum(학년5반1["영어"]) + sum(학년5반2["영어"]) + sum(학년5반3["영어"]) + sum(학년5반4["영어"])
점수평균5학년영어 = 점수합계5학년영어 / 80

점수합계5학년수학 = sum(학년5반1["수학"]) + sum(학년5반2["수학"]) + sum(학년5반3["수학"]) + sum(학년5반4["수학"])
점수평균5학년수학 = 점수합계5학년수학 / 80

점수합계6학년국어 = sum(학년6반1["국어"]) + sum(학년6반2["국어"]) + sum(학년6반3["국어"]) + sum(학년6반4["국어"])
점수평균6학년국어 = 점수합계6학년국어 / 80

점수합계6학년영어 = sum(학년6반1["영어"]) + sum(학년6반2["영어"]) + sum(학년6반3["영어"]) + sum(학년6반4["영어"])
점수평균6학년영어 = 점수합계6학년영어 / 80

점수합계6학년수학 = sum(학년6반1["수학"]) + sum(학년6반2["수학"]) + sum(학년6반3["수학"]) + sum(학년6반4["수학"])
점수평균6학년수학 = 점수합계6학년수학 / 80

print("1학년 국어 점수 평균:", 점수평균1학년국어)
print("1학년 영어 점수 평균:", 점수평균1학년영어)
print("1학년 수학 점수 평균:", 점수평균1학년수학)

print("2학년 국어 점수 평균:", 점수평균2학년국어)
print("2학년 영어 점수 평균:", 점수평균2학년영어)
print("2학년 수학 점수 평균:", 점수평균2학년수학)

print("3학년 국어 점수 평균:", 점수평균3학년국어)
print("3학년 영어 점수 평균:", 점수평균3학년영어)
print("3학년 수학 점수 평균:", 점수평균3학년수학)

print("4학년 국어 점수 평균:", 점수평균4학년국어)
print("4학년 영어 점수 평균:", 점수평균4학년영어)
print("4학년 수학 점수 평균:", 점수평균4학년수학)

print("5학년 국어 점수 평균:", 점수평균5학년국어)
print("5학년 영어 점수 평균:", 점수평균5학년영어)
print("5학년 수학 점수 평균:", 점수평균5학년수학)

print("6학년 국어 점수 평균:", 점수평균6학년국어)
print("6학년 영어 점수 평균:", 점수평균6학년영어)
print("6학년 수학 점수 평균:", 점수평균6학년수학)
# Out:
# 1학년 국어 점수 평균: 49.55
# 1학년 영어 점수 평균: 45.0375
# 1학년 수학 점수 평균: 46.1
# 2학년 국어 점수 평균: 54.7375
# 2학년 영어 점수 평균: 52.7125
# 2학년 수학 점수 평균: 53.8
# 3학년 국어 점수 평균: 56.7875
# 3학년 영어 점수 평균: 51.7875
# 3학년 수학 점수 평균: 55.65
# 4학년 국어 점수 평균: 46.875
# 4학년 영어 점수 평균: 46.25
# 4학년 수학 점수 평균: 50.7375
# 5학년 국어 점수 평균: 52.9625
# 5학년 영어 점수 평균: 50.5625
# 5학년 수학 점수 평균: 50.6125
# 6학년 국어 점수 평균: 50.65
# 6학년 영어 점수 평균: 53.725
# 6학년 수학 점수 평균: 49.075

# %%
점수합계1학년1반국어 = 0
for 점수 in 학년1반1["국어"]:
    점수합계1학년1반국어 = 점수합계1학년1반국어 + 점수
국어평균1학년1반 = 점수합계1학년1반국어 / len(학년1반1["국어"])

점수합계1학년1반영어 = 0
for 점수 in 학년1반1["영어"]:
    점수합계1학년1반영어 = 점수합계1학년1반영어 + 점수
영어평균1학년1반 = 점수합계1학년1반영어 / len(학년1반1["영어"])

점수합계1학년1반수학 = 0
for 점수 in 학년1반1["수학"]:
    점수합계1학년1반수학 = 점수합계1학년1반수학 + 점수
수학평균1학년1반 = 점수합계1학년1반수학 / len(학년1반1["수학"])

점수합계1학년2반국어 = 0
for 점수 in 학년1반2["국어"]:
    점수합계1학년2반국어 = 점수합계1학년2반국어 + 점수
국어평균1학년2반 = 점수합계1학년2반국어 / len(학년1반2["국어"])

점수합계1학년2반영어 = 0
for 점수 in 학년1반2["영어"]:
    점수합계1학년2반영어 = 점수합계1학년2반영어 + 점수
영어평균1학년2반 = 점수합계1학년2반영어 / len(학년1반2["영어"])

점수합계1학년2반수학 = 0
for 점수 in 학년1반2["수학"]:
    점수합계1학년2반수학 = 점수합계1학년2반수학 + 점수
수학평균1학년2반 = 점수합계1학년2반수학 / len(학년1반2["수학"])

점수합계1학년3반국어 = 0
for 점수 in 학년1반3["국어"]:
    점수합계1학년3반국어 = 점수합계1학년3반국어 + 점수
국어평균1학년3반 = 점수합계1학년3반국어 / len(학년1반3["국어"])

점수합계1학년3반영어 = 0
for 점수 in 학년1반3["영어"]:
    점수합계1학년3반영어 = 점수합계1학년3반영어 + 점수
영어평균1학년3반 = 점수합계1학년3반영어 / len(학년1반3["영어"])

점수합계1학년3반수학 = 0
for 점수 in 학년1반3["수학"]:
    점수합계1학년3반수학 = 점수합계1학년3반수학 + 점수
수학평균1학년3반 = 점수합계1학년3반수학 / len(학년1반3["수학"])

점수합계1학년4반국어 = 0
for 점수 in 학년1반4["국어"]:
    점수합계1학년4반국어 = 점수합계1학년4반국어 + 점수
국어평균1학년4반 = 점수합계1학년4반국어 / len(학년1반4["국어"])

점수합계1학년4반영어 = 0
for 점수 in 학년1반4["영어"]:
    점수합계1학년4반영어 = 점수합계1학년4반영어 + 점수
영어평균1학년4반 = 점수합계1학년4반영어 / len(학년1반4["영어"])

점수합계1학년4반수학 = 0
for 점수 in 학년1반4["수학"]:
    점수합계1학년4반수학 = 점수합계1학년4반수학 + 점수
수학평균1학년4반 = 점수합계1학년4반수학 / len(학년1반4["수학"])

점수합계2학년1반국어 = 0
for 점수 in 학년2반1["국어"]:
    점수합계2학년1반국어 = 점수합계2학년1반국어 + 점수
국어평균2학년1반 = 점수합계2학년1반국어 / len(학년2반1["국어"])

점수합계2학년1반영어 = 0
for 점수 in 학년2반1["영어"]:
    점수합계2학년1반영어 = 점수합계2학년1반영어 + 점수
영어평균2학년1반 = 점수합계2학년1반영어 / len(학년2반1["영어"])

점수합계2학년1반수학 = 0
for 점수 in 학년2반1["수학"]:
    점수합계2학년1반수학 = 점수합계2학년1반수학 + 점수
수학평균2학년1반 = 점수합계2학년1반수학 / len(학년2반1["수학"])

점수합계2학년2반국어 = 0
for 점수 in 학년2반2["국어"]:
    점수합계2학년2반국어 = 점수합계2학년2반국어 + 점수
국어평균2학년2반 = 점수합계2학년2반국어 / len(학년2반2["국어"])

점수합계2학년2반영어 = 0
for 점수 in 학년2반2["영어"]:
    점수합계2학년2반영어 = 점수합계2학년2반영어 + 점수
영어평균2학년2반 = 점수합계2학년2반영어 / len(학년2반2["영어"])

점수합계2학년2반수학 = 0
for 점수 in 학년2반2["수학"]:
    점수합계2학년2반수학 = 점수합계2학년2반수학 + 점수
수학평균2학년2반 = 점수합계2학년2반수학 / len(학년2반2["수학"])

점수합계2학년3반국어 = 0
for 점수 in 학년2반3["국어"]:
    점수합계2학년3반국어 = 점수합계2학년3반국어 + 점수
국어평균2학년3반 = 점수합계2학년3반국어 / len(학년2반3["국어"])

점수합계2학년3반영어 = 0
for 점수 in 학년2반3["영어"]:
    점수합계2학년3반영어 = 점수합계2학년3반영어 + 점수
영어평균2학년3반 = 점수합계2학년3반영어 / len(학년2반3["영어"])

점수합계2학년3반수학 = 0
for 점수 in 학년2반3["수학"]:
    점수합계2학년3반수학 = 점수합계2학년3반수학 + 점수
수학평균2학년3반 = 점수합계2학년3반수학 / len(학년2반3["수학"])

점수합계2학년4반국어 = 0
for 점수 in 학년2반4["국어"]:
    점수합계2학년4반국어 = 점수합계2학년4반국어 + 점수
국어평균2학년4반 = 점수합계2학년4반국어 / len(학년2반4["국어"])

점수합계2학년4반영어 = 0
for 점수 in 학년2반4["영어"]:
    점수합계2학년4반영어 = 점수합계2학년4반영어 + 점수
영어평균2학년4반 = 점수합계2학년4반영어 / len(학년2반4["영어"])

점수합계2학년4반수학 = 0
for 점수 in 학년2반4["수학"]:
    점수합계2학년4반수학 = 점수합계2학년4반수학 + 점수
수학평균2학년4반 = 점수합계2학년4반수학 / len(학년2반4["수학"])

점수합계3학년1반국어 = 0
for 점수 in 학년3반1["국어"]:
    점수합계3학년1반국어 = 점수합계3학년1반국어 + 점수
국어평균3학년1반 = 점수합계3학년1반국어 / len(학년3반1["국어"])

점수합계3학년1반영어 = 0
for 점수 in 학년3반1["영어"]:
    점수합계3학년1반영어 = 점수합계3학년1반영어 + 점수
영어평균3학년1반 = 점수합계3학년1반영어 / len(학년3반1["영어"])

점수합계3학년1반수학 = 0
for 점수 in 학년3반1["수학"]:
    점수합계3학년1반수학 = 점수합계3학년1반수학 + 점수
수학평균3학년1반 = 점수합계3학년1반수학 / len(학년3반1["수학"])

점수합계3학년2반국어 = 0
for 점수 in 학년3반2["국어"]:
    점수합계3학년2반국어 = 점수합계3학년2반국어 + 점수
국어평균3학년2반 = 점수합계3학년2반국어 / len(학년3반2["국어"])

점수합계3학년2반영어 = 0
for 점수 in 학년3반2["영어"]:
    점수합계3학년2반영어 = 점수합계3학년2반영어 + 점수
영어평균3학년2반 = 점수합계3학년2반영어 / len(학년3반2["영어"])

점수합계3학년2반수학 = 0
for 점수 in 학년3반2["수학"]:
    점수합계3학년2반수학 = 점수합계3학년2반수학 + 점수
수학평균3학년2반 = 점수합계3학년2반수학 / len(학년3반2["수학"])

점수합계3학년3반국어 = 0
for 점수 in 학년4반3["국어"]:
    점수합계3학년3반국어 = 점수합계3학년3반국어 + 점수
국어평균3학년3반 = 점수합계3학년3반국어 / len(학년4반3["국어"])

점수합계3학년3반영어 = 0
for 점수 in 학년4반3["영어"]:
    점수합계3학년3반영어 = 점수합계3학년3반영어 + 점수
영어평균3학년3반 = 점수합계3학년3반영어 / len(학년3반3["영어"])

점수합계3학년3반수학 = 0
for 점수 in 학년3반3["수학"]:
    점수합계3학년3반수학 = 점수합계3학년3반수학 + 점수
수학평균3학년3반 = 점수합계3학년3반수학 / len(학년3반3["수학"])

점수합계3학년4반국어 = 0
for 점수 in 학년3반4["국어"]:
    점수합계3학년4반국어 = 점수합계3학년4반국어 + 점수
국어평균3학년4반 = 점수합계3학년4반국어 / len(학년3반4["국어"])

점수합계3학년4반영어 = 0
for 점수 in 학년3반4["영어"]:
    점수합계3학년4반영어 = 점수합계3학년4반영어 + 점수
영어평균3학년4반 = 점수합계3학년4반영어 / len(학년3반4["영어"])

점수합계3학년4반수학 = 0
for 점수 in 학년3반4["수학"]:
    점수합계3학년4반수학 = 점수합계3학년4반수학 + 점수
수학평균3학년4반 = 점수합계3학년4반수학 / len(학년3반4["수학"])

점수합계4학년1반국어 = 0
for 점수 in 학년4반1["국어"]:
    점수합계4학년1반국어 = 점수합계4학년1반국어 + 점수
국어평균4학년1반 = 점수합계4학년1반국어 / len(학년4반1["국어"])

점수합계4학년1반영어 = 0
for 점수 in 학년4반1["영어"]:
    점수합계4학년1반영어 = 점수합계4학년1반영어 + 점수
영어평균4학년1반 = 점수합계4학년1반영어 / len(학년4반1["영어"])

점수합계4학년1반수학 = 0
for 점수 in 학년4반1["수학"]:
    점수합계4학년1반수학 = 점수합계4학년1반수학 + 점수
수학평균4학년1반 = 점수합계4학년1반수학 / len(학년4반1["수학"])

점수합계4학년2반국어 = 0
for 점수 in 학년4반2["국어"]:
    점수합계4학년2반국어 = 점수합계4학년2반국어 + 점수
국어평균4학년2반 = 점수합계4학년2반국어 / len(학년4반2["국어"])

점수합계4학년2반영어 = 0
for 점수 in 학년4반2["영어"]:
    점수합계4학년2반영어 = 점수합계4학년2반영어 + 점수
영어평균4학년2반 = 점수합계4학년2반영어 / len(학년4반2["영어"])

점수합계4학년2반수학 = 0
for 점수 in 학년4반2["수학"]:
    점수합계4학년2반수학 = 점수합계4학년2반수학 + 점수
수학평균4학년2반 = 점수합계4학년2반수학 / len(학년4반2["수학"])

점수합계4학년3반국어 = 0
for 점수 in 학년4반3["국어"]:
    점수합계4학년3반국어 = 점수합계4학년3반국어 + 점수
국어평균4학년3반 = 점수합계4학년3반국어 / len(학년4반3["국어"])

점수합계4학년3반영어 = 0
for 점수 in 학년4반3["영어"]:
    점수합계4학년3반영어 = 점수합계4학년3반영어 + 점수
영어평균4학년3반 = 점수합계4학년3반영어 / len(학년4반3["영어"])

점수합계4학년3반수학 = 0
for 점수 in 학년4반3["수학"]:
    점수합계4학년3반수학 = 점수합계4학년3반수학 + 점수
수학평균4학년3반 = 점수합계4학년3반수학 / len(학년4반3["수학"])

점수합계4학년4반국어 = 0
for 점수 in 학년4반4["국어"]:
    점수합계4학년4반국어 = 점수합계4학년4반국어 + 점수
국어평균4학년4반 = 점수합계4학년4반국어 / len(학년4반4["국어"])

점수합계4학년4반영어 = 0
for 점수 in 학년4반4["영어"]:
    점수합계4학년4반영어 = 점수합계4학년4반영어 + 점수
영어평균4학년4반 = 점수합계4학년4반영어 / len(학년4반4["영어"])

점수합계4학년4반수학 = 0
for 점수 in 학년4반4["수학"]:
    점수합계4학년4반수학 = 점수합계4학년4반수학 + 점수
수학평균4학년4반 = 점수합계4학년4반수학 / len(학년4반4["수학"])


점수합계5학년1반국어 = 0
for 점수 in 학년5반1["국어"]:
    점수합계5학년1반국어 = 점수합계5학년1반국어 + 점수
국어평균5학년1반 = 점수합계5학년1반국어 / len(학년5반1["국어"])

점수합계5학년1반영어 = 0
for 점수 in 학년5반1["영어"]:
    점수합계5학년1반영어 = 점수합계5학년1반영어 + 점수
영어평균5학년1반 = 점수합계5학년1반영어 / len(학년5반1["영어"])

점수합계5학년1반수학 = 0
for 점수 in 학년5반1["수학"]:
    점수합계5학년1반수학 = 점수합계5학년1반수학 + 점수
수학평균5학년1반 = 점수합계5학년1반수학 / len(학년5반1["수학"])

점수합계5학년2반국어 = 0
for 점수 in 학년5반2["국어"]:
    점수합계5학년2반국어 = 점수합계5학년2반국어 + 점수
국어평균5학년2반 = 점수합계5학년2반국어 / len(학년5반2["국어"])

점수합계5학년2반영어 = 0
for 점수 in 학년5반2["영어"]:
    점수합계5학년2반영어 = 점수합계5학년2반영어 + 점수
영어평균5학년2반 = 점수합계5학년2반영어 / len(학년5반2["영어"])

점수합계5학년2반수학 = 0
for 점수 in 학년5반2["수학"]:
    점수합계5학년2반수학 = 점수합계5학년2반수학 + 점수
수학평균5학년2반 = 점수합계5학년2반수학 / len(학년5반2["수학"])

점수합계5학년3반국어 = 0
for 점수 in 학년5반3["국어"]:
    점수합계5학년3반국어 = 점수합계5학년3반국어 + 점수
국어평균5학년3반 = 점수합계5학년3반국어 / len(학년5반3["국어"])

점수합계5학년3반영어 = 0
for 점수 in 학년5반3["영어"]:
    점수합계5학년3반영어 = 점수합계5학년3반영어 + 점수
영어평균5학년3반 = 점수합계5학년3반영어 / len(학년5반3["영어"])

점수합계5학년3반수학 = 0
for 점수 in 학년5반3["수학"]:
    점수합계5학년3반수학 = 점수합계5학년3반수학 + 점수
수학평균5학년3반 = 점수합계5학년3반수학 / len(학년5반3["수학"])

점수합계5학년4반국어 = 0
for 점수 in 학년5반4["국어"]:
    점수합계5학년4반국어 = 점수합계5학년4반국어 + 점수
국어평균5학년4반 = 점수합계5학년4반국어 / len(학년5반4["국어"])

점수합계5학년4반영어 = 0
for 점수 in 학년5반4["영어"]:
    점수합계5학년4반영어 = 점수합계5학년4반영어 + 점수
영어평균5학년4반 = 점수합계5학년4반영어 / len(학년5반4["영어"])

점수합계5학년4반수학 = 0
for 점수 in 학년5반4["수학"]:
    점수합계5학년4반수학 = 점수합계5학년4반수학 + 점수
수학평균5학년4반 = 점수합계5학년4반수학 / len(학년5반4["수학"])


점수합계6학년1반국어 = 0
for 점수 in 학년6반1["국어"]:
    점수합계6학년1반국어 = 점수합계6학년1반국어 + 점수
국어평균6학년1반 = 점수합계6학년1반국어 / len(학년6반1["국어"])

점수합계6학년1반영어 = 0
for 점수 in 학년6반1["영어"]:
    점수합계6학년1반영어 = 점수합계6학년1반영어 + 점수
영어평균6학년1반 = 점수합계6학년1반영어 / len(학년6반1["영어"])

점수합계6학년1반수학 = 0
for 점수 in 학년6반1["수학"]:
    점수합계6학년1반수학 = 점수합계6학년1반수학 + 점수
수학평균6학년1반 = 점수합계6학년1반수학 / len(학년6반1["수학"])

점수합계6학년2반국어 = 0
for 점수 in 학년6반2["국어"]:
    점수합계6학년2반국어 = 점수합계6학년2반국어 + 점수
국어평균6학년2반 = 점수합계6학년2반국어 / len(학년6반2["국어"])

점수합계6학년2반영어 = 0
for 점수 in 학년6반2["영어"]:
    점수합계6학년2반영어 = 점수합계6학년2반영어 + 점수
영어평균6학년2반 = 점수합계6학년2반영어 / len(학년6반2["영어"])

점수합계6학년2반수학 = 0
for 점수 in 학년6반2["수학"]:
    점수합계6학년2반수학 = 점수합계6학년2반수학 + 점수
수학평균6학년2반 = 점수합계6학년2반수학 / len(학년6반2["수학"])

점수합계6학년3반국어 = 0
for 점수 in 학년6반3["국어"]:
    점수합계6학년3반국어 = 점수합계6학년3반국어 + 점수
국어평균6학년3반 = 점수합계6학년3반국어 / len(학년6반3["국어"])

점수합계6학년3반영어 = 0
for 점수 in 학년6반3["영어"]:
    점수합계6학년3반영어 = 점수합계6학년3반영어 + 점수
영어평균6학년3반 = 점수합계6학년3반영어 / len(학년6반3["영어"])

점수합계6학년3반수학 = 0
for 점수 in 학년6반3["수학"]:
    점수합계6학년3반수학 = 점수합계6학년3반수학 + 점수
수학평균6학년3반 = 점수합계6학년3반수학 / len(학년6반3["수학"])

점수합계6학년4반국어 = 0
for 점수 in 학년6반4["국어"]:
    점수합계6학년4반국어 = 점수합계6학년4반국어 + 점수
국어평균6학년4반 = 점수합계6학년4반국어 / len(학년6반4["국어"])

점수합계6학년4반영어 = 0
for 점수 in 학년6반4["영어"]:
    점수합계6학년4반영어 = 점수합계6학년4반영어 + 점수
영어평균6학년4반 = 점수합계6학년4반영어 / len(학년6반4["영어"])

점수합계6학년4반수학 = 0
for 점수 in 학년6반4["수학"]:
    점수합계6학년4반수학 = 점수합계6학년4반수학 + 점수
수학평균6학년4반 = 점수합계6학년4반수학 / len(학년6반4["수학"])

평균 = [국어평균1학년1반, 영어평균1학년1반, 수학평균1학년1반,
        국어평균1학년2반, 영어평균1학년2반, 수학평균1학년2반,
        국어평균1학년3반, 영어평균1학년3반, 수학평균1학년3반,
        국어평균1학년4반, 영어평균1학년4반, 수학평균1학년4반,
        국어평균2학년1반, 영어평균2학년1반, 수학평균2학년1반,
        국어평균2학년2반, 영어평균2학년2반, 수학평균2학년2반,
        국어평균2학년3반, 영어평균2학년3반, 수학평균2학년3반,
        국어평균2학년4반, 영어평균2학년4반, 수학평균2학년4반,
        국어평균3학년1반, 영어평균3학년1반, 수학평균3학년1반,
        국어평균3학년2반, 영어평균3학년2반, 수학평균3학년2반,
        국어평균3학년3반, 영어평균3학년3반, 수학평균3학년3반,
        국어평균3학년4반, 영어평균3학년4반, 수학평균3학년4반,
        국어평균4학년1반, 영어평균4학년1반, 수학평균4학년1반,
        국어평균4학년2반, 영어평균4학년2반, 수학평균4학년2반,
        국어평균4학년3반, 영어평균4학년3반, 수학평균4학년3반,
        국어평균4학년4반, 영어평균4학년4반, 수학평균4학년4반,
        국어평균5학년1반, 영어평균5학년1반, 수학평균5학년1반,
        국어평균5학년2반, 영어평균5학년2반, 수학평균5학년2반,
        국어평균5학년3반, 영어평균5학년3반, 수학평균5학년3반,
        국어평균5학년4반, 영어평균5학년4반, 수학평균5학년4반,
        국어평균6학년1반, 영어평균6학년1반, 수학평균6학년1반,
        국어평균6학년2반, 영어평균6학년2반, 수학평균6학년2반,
        국어평균6학년3반, 영어평균6학년3반, 수학평균6학년3반,
        국어평균6학년4반, 영어평균6학년4반, 수학평균6학년4반]

선택 = random.choice(평균)
선택인덱스 = 평균.index(선택)
학년 = (선택인덱스 // 12) + 1
반 = ((선택인덱스 % 12) // 3) + 1

과목 = ["국어", "영어", "수학"]
과목번호 = 선택인덱스 % 3
과목명 = 과목[과목번호]

print(f'{학년}학년 {반}반 {과목명} 평균:', random.choice(평균))
# Out:
# 5학년 3반 국어 평균: 47.05

# %%
학생1_성적 = [random.choice([*점수모음[0], *점수모음[3], *점수모음[6], *점수모음[9]]),
            random.choice([*점수모음[1], *점수모음[4], *점수모음[7], *점수모음[10]]),
            random.choice([*점수모음[2], *점수모음[5], *점수모음[8], *점수모음[11]])]

학생2_성적 = [random.choice([*점수모음[12], *점수모음[15], *점수모음[18], *점수모음[21]]),
            random.choice([*점수모음[13], *점수모음[16], *점수모음[19], *점수모음[22]]),
            random.choice([*점수모음[14], *점수모음[17], *점수모음[20], *점수모음[23]])]

학생3_성적 = [random.choice([*점수모음[24], *점수모음[27], *점수모음[30], *점수모음[33]]),
            random.choice([*점수모음[25], *점수모음[28], *점수모음[31], *점수모음[34]]),
            random.choice([*점수모음[26], *점수모음[29], *점수모음[32], *점수모음[35]])]

학생4_성적 = [random.choice([*점수모음[36], *점수모음[39], *점수모음[42], *점수모음[45]]),
            random.choice([*점수모음[37], *점수모음[40], *점수모음[43], *점수모음[46]]),
            random.choice([*점수모음[38], *점수모음[41], *점수모음[44], *점수모음[47]])]

학생5_성적 = [random.choice([*점수모음[48], *점수모음[51], *점수모음[54], *점수모음[57]]),
            random.choice([*점수모음[49], *점수모음[52], *점수모음[55], *점수모음[58]]),
            random.choice([*점수모음[50], *점수모음[53], *점수모음[56], *점수모음[59]])]

학생6_성적 = [random.choice([*점수모음[60], *점수모음[63], *점수모음[66], *점수모음[69]]),
            random.choice([*점수모음[61], *점수모음[64], *점수모음[67], *점수모음[70]]),
            random.choice([*점수모음[62], *점수모음[65], *점수모음[68], *점수모음[71]])]

# %%
국어_최고점 = max(max(학년1반1["국어"]), max(학년1반2["국어"]), max(학년1반3["국어"]), max(학년1반4["국어"]))
국어_최저점 = min(min(학년1반1["국어"]), min(학년1반2["국어"]), min(학년1반3["국어"]), min(학년1반4["국어"]))
print("5학년 국어 최고점:", 국어_최고점); print("1학년 국어 최저점:", 국어_최저점)

영어_최고점 = max(max(학년1반1["영어"]), max(학년1반2["영어"]), max(학년1반3["영어"]), max(학년1반4["영어"]))
영어_최저점 = min(min(학년1반1["영어"]), min(학년1반2["영어"]), min(학년1반3["영어"]), min(학년1반4["영어"]))
print("1학년 영어 최고점:", 영어_최고점); print("1학년 영어 최저점:", 영어_최저점)

수학_최고점 = max(max(학년1반1["수학"]), max(학년1반2["수학"]), max(학년1반3["수학"]), max(학년1반4["수학"]))
수학_최저점 = min(min(학년1반1["수학"]), min(학년1반2["수학"]), min(학년1반3["수학"]), min(학년1반4["수학"]))
print("1학년 수학 최고점:", 수학_최고점); print("1학년 수학 최저점:", 수학_최저점)

국어_최고점 = max(max(학년2반1["국어"]), max(학년2반2["국어"]), max(학년2반3["국어"]), max(학년2반4["국어"]))
국어_최저점 = min(min(학년2반1["국어"]), min(학년2반2["국어"]), min(학년2반3["국어"]), min(학년2반4["국어"]))
print("2학년 국어 최고점:", 국어_최고점); print("2학년 국어 최저점:", 국어_최저점)

영어_최고점 = max(max(학년2반1["영어"]), max(학년2반2["영어"]), max(학년2반3["영어"]), max(학년2반4["영어"]))
영어_최저점 = min(min(학년2반1["영어"]), min(학년2반2["영어"]), min(학년2반3["영어"]), min(학년2반4["영어"]))
print("2학년 영어 최고점:", 영어_최고점); print("2학년 영어 최저점:", 영어_최저점)

수학_최고점 = max(max(학년2반1["수학"]), max(학년2반2["수학"]), max(학년2반3["수학"]), max(학년2반4["수학"]))
수학_최저점 = min(min(학년2반1["수학"]), min(학년2반2["수학"]), min(학년2반3["수학"]), min(학년2반4["수학"]))
print("2학년 수학 최고점:", 수학_최고점); print("2학년 수학 최저점:", 수학_최저점)

국어_최고점 = max(max(학년3반1["국어"]), max(학년3반2["국어"]), max(학년3반3["국어"]), max(학년3반4["국어"]))
국어_최저점 = min(min(학년3반1["국어"]), min(학년3반2["국어"]), min(학년3반3["국어"]), min(학년3반4["국어"]))
print("3학년 국어 최고점:", 국어_최고점); print("3학년 국어 최저점:", 국어_최저점)

영어_최고점 = max(max(학년3반1["영어"]), max(학년3반2["영어"]), max(학년3반3["영어"]), max(학년3반4["영어"]))
영어_최저점 = min(min(학년3반1["영어"]), min(학년3반2["영어"]), min(학년3반3["영어"]), min(학년3반4["영어"]))
print("3학년 영어 최고점:", 영어_최고점); print("3학년 영어 최저점:", 영어_최저점)

수학_최고점 = max(max(학년3반1["수학"]), max(학년3반2["수학"]), max(학년3반3["수학"]), max(학년3반4["수학"]))
수학_최저점 = min(min(학년3반1["수학"]), min(학년3반2["수학"]), min(학년3반3["수학"]), min(학년3반4["수학"]))
print("3학년 수학 최고점:", 수학_최고점); print("3학년 수학 최저점:", 수학_최저점)

국어_최고점 = max(max(학년4반1["국어"]), max(학년4반2["국어"]), max(학년4반3["국어"]), max(학년4반4["국어"]))
국어_최저점 = min(min(학년4반1["국어"]), min(학년4반2["국어"]), min(학년4반3["국어"]), min(학년4반4["국어"]))
print("4학년 국어 최고점:", 국어_최고점); print("4학년 국어 최저점:", 국어_최저점)

영어_최고점 = max(max(학년4반1["영어"]), max(학년4반2["영어"]), max(학년4반3["영어"]), max(학년4반4["영어"]))
영어_최저점 = min(min(학년4반1["영어"]), min(학년4반2["영어"]), min(학년4반3["영어"]), min(학년4반4["영어"]))
print("4학년 영어 최고점:", 영어_최고점); print("4학년 영어 최저점:", 영어_최저점)

수학_최고점 = max(max(학년4반1["수학"]), max(학년4반2["수학"]), max(학년4반3["수학"]), max(학년4반4["수학"]))
수학_최저점 = min(min(학년4반1["수학"]), min(학년4반2["수학"]), min(학년4반3["수학"]), min(학년4반4["수학"]))
print("4학년 수학 최고점:", 수학_최고점); print("4학년 수학 최저점:", 수학_최저점)

국어_최고점 = max(max(학년5반1["국어"]), max(학년5반2["국어"]), max(학년5반3["국어"]), max(학년5반4["국어"]))
국어_최저점 = min(min(학년5반1["국어"]), min(학년5반2["국어"]), min(학년5반3["국어"]), min(학년5반4["국어"]))
print("5학년 국어 최고점:", 국어_최고점); print("5학년 국어 최저점:", 국어_최저점)

영어_최고점 = max(max(학년5반1["영어"]), max(학년5반2["영어"]), max(학년5반3["영어"]), max(학년5반4["영어"]))
영어_최저점 = min(min(학년5반1["영어"]), min(학년5반2["영어"]), min(학년5반3["영어"]), min(학년5반4["영어"]))
print("5학년 영어 최고점:", 영어_최고점); print("5학년 영어 최저점:", 영어_최저점)

수학_최고점 = max(max(학년5반1["수학"]), max(학년5반2["수학"]), max(학년5반3["수학"]), max(학년5반4["수학"]))
수학_최저점 = min(min(학년5반1["수학"]), min(학년5반2["수학"]), min(학년5반3["수학"]), min(학년5반4["수학"]))
print("5학년 수학 최고점:", 수학_최고점); print("5학년 수학 최저점:", 수학_최저점)

국어_최고점 = max(max(학년6반1["국어"]), max(학년6반2["국어"]), max(학년6반3["국어"]), max(학년6반4["국어"]))
국어_최저점 = min(min(학년6반1["국어"]), min(학년6반2["국어"]), min(학년6반3["국어"]), min(학년6반4["국어"]))
print("6학년 국어 최고점:", 국어_최고점); print("6학년 국어 최저점:", 국어_최저점)

영어_최고점 = max(max(학년6반1["영어"]), max(학년6반2["영어"]), max(학년6반3["영어"]), max(학년6반4["영어"]))
영어_최저점 = min(min(학년6반1["영어"]), min(학년6반2["영어"]), min(학년6반3["영어"]), min(학년6반4["영어"]))
print("6학년 영어 최고점:", 영어_최고점); print("6학년 영어 최저점:", 영어_최저점)

수학_최고점 = max(max(학년6반1["수학"]), max(학년6반2["수학"]), max(학년6반3["수학"]), max(학년6반4["수학"]))
수학_최저점 = min(min(학년6반1["수학"]), min(학년6반2["수학"]), min(학년6반3["수학"]), min(학년6반4["수학"]))
print("6학년 수학 최고점:", 수학_최고점); print("6학년 수학 최저점:", 수학_최저점)
# Out:
# 5학년 국어 최고점: 100
# 1학년 국어 최저점: 1
# 1학년 영어 최고점: 100
# 1학년 영어 최저점: 0
# 1학년 수학 최고점: 98
# 1학년 수학 최저점: 0
# 2학년 국어 최고점: 100
# 2학년 국어 최저점: 0
# 2학년 영어 최고점: 100
# 2학년 영어 최저점: 1
# 2학년 수학 최고점: 100
# 2학년 수학 최저점: 1
# 3학년 국어 최고점: 100
# 3학년 국어 최저점: 0
# 3학년 영어 최고점: 97
# 3학년 영어 최저점: 1
# 3학년 수학 최고점: 100
# 3학년 수학 최저점: 0
# 4학년 국어 최고점: 100
# 4학년 국어 최저점: 0
# 4학년 영어 최고점: 97
# 4학년 영어 최저점: 0
# 4학년 수학 최고점: 95
# 4학년 수학 최저점: 0
# 5학년 국어 최고점: 100
# 5학년 국어 최저점: 0
# 5학년 영어 최고점: 95
# 5학년 영어 최저점: 1
# 5학년 수학 최고점: 99
# 5학년 수학 최저점: 1
# 6학년 국어 최고점: 100
# 6학년 국어 최저점: 0
# 6학년 영어 최고점: 100
# 6학년 영어 최저점: 0
# 6학년 수학 최고점: 100
# 6학년 수학 최저점: 3
